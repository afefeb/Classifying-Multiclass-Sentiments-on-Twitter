# %%
import pandas as pd

# %%
df_label = pd.read_csv('C:\\Users\\thebl\\Documents\\Lomba\\SatDat2024\\FullSenyum-SatriaData2024\\Code\\Preprocessing\\cleaned_final')
df_label
# Out:
#                                                    text  \
# 0     kunjungan prabowo meresmikan menyerahkan proye...
# 1     anies tepuk tangan meriah rektor mewajibkan ma...
# 2     memang benar sih pendukung anies dengan penduk...
# 3     anies bersikap kritis kinerja prabowo dianggap...
# 4     anies baswedan harap asn tni polri pegang sump...
# ...                                                 ...
# 4276  ngeliat debat kemarin pas prabowo kicep kekira...
# 4277  masyarakat prabowo gibran memiliki visi sejala...
# 4278  imo both are irrational but irrational tbh but...
# 4279  look at that ganjar berkecimpung lgislatif eks...
# 4280  acara memasak calon presiden nomor urut 2 meng...
#
#                         label  \
# 0            Sumber Daya Alam
# 1                     Politik
# 2                   Demografi
# 3                     Politik
# 4                     Politik
# ...                       ...
# 4276                  Politik
# 4277                  Politik
# ...

# %%
df_label['label_angka'] = df_label.label.map({
    'Politik' : 0,
    'Sosial Budaya'  : 1,
    'Ideologi' : 2,
    'Pertahanan dan Keamanan' : 3,
    'Ekonomi' : 4,
    'Sumber Daya Alam' : 5,
    'Demografi' : 6,
    'Geografi' : 7
})
df_label.head()
# Out:
#                                                 text             label  \
# 0  kunjungan prabowo meresmikan menyerahkan proye...  Sumber Daya Alam
# 1  anies tepuk tangan meriah rektor mewajibkan ma...           Politik
# 2  memang benar sih pendukung anies dengan penduk...         Demografi
# 3  anies bersikap kritis kinerja prabowo dianggap...           Politik
# 4  anies baswedan harap asn tni polri pegang sump...           Politik
#
#                                         stemmed_text  label_angka
# 0  kunjung prabowo resmi serah proyek bantu air b...            5
# 1  anies tepuk tangan riah rektor wajib mata kuli...            0
# 2  memang benar sih dukung anies dengan dukung pr...            6
# 3  anies sikap kritis kerja prabowo anggap sopan ...            0
# 4  anies baswedan harap asn tni polri pegang sump...            0

# %%
df_label.to_csv('cleaned_final_label.csv', index=False)
